# %%
# !pip install epyk
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Collecting epyk
#   Downloading epyk-1.0.10-py2.py3-none-any.whl (891 kB)
#      |████████████████████████████████| 891 kB 5.9 MB/s eta 0:00:01
# Installing collected packages: epyk
# Successfully installed epyk-1.0.10

# %%
from epyk.core.Page import Report

# Create a basic report object
rptObj = Report()

languages = [
  {"name": 'C', 'type': 'code', 'rating': 17.07, 'change': 12.82},
  {"name": 'Java', 'type': 'code', 'rating': 16.28, 'change': 0.28},
  {"name": 'Python', 'type': 'script', 'rating': 9.12, 'change': 1.29},
  {"name": 'C++', 'type': 'code', 'rating': 6.13, 'change': -1.97},
  {"name": 'C#', 'type': 'code', 'rating': 4.29, 'change': 0.3},
  {"name": 'Visual Basic', 'type': 'script', 'rating': 4.18, 'change': -1.01},
  {"name": 'JavaScript', 'type': 'script', 'rating': 2.68, 'change': -0.01},
  {"name": 'PHP', 'type': 'script', 'rating': 2.49, 'change': 0},
  {"name": 'SQL', 'type': 'script', 'rating': 2.09, 'change': -0.47},
  {"name": 'R', 'type': 'script', 'rating': 1.85, 'change': 0.90},
]


# Create a table
tb = rptObj.ui.tables.pivot(languages, ['name'], ['type'])
tb.aggregators.sum('rating')


tb2 = rptObj.ui.tables.pivot(languages, ['name'], ['type'])
tb2.aggregators.sum('rating')

row = rptObj.ui.row([tb, tb2])
row[1].style.css.padding_left = '10px'

rptObj.outs.jupyter()
# Out:
# <head>
# <style>
#     .cssdivnoborder {margin: 0 ;clear: both ;padding: 0 ;border: 0 ;}
# .pvtTable tr td {font-size: 8pt ;padding: 5px ;color: #000000 !IMPORTANT ;border: 1px solid #81c784 !IMPORTANT ;}
# .pvtTable tr td:hover {color: #000000 !IMPORTANT ;background-color: #a5d6a7 !IMPORTANT ;}
# .pvtAxisContainer {color: #f5f5f5 ;}
# .pvtFilterBox {color: #f5f5f5 ;}
# .pvtVals {color: #000000 ;}
# .pvtColLabel, .pvtAxisLabel, .pvtRowLabel, .pvtTotalLabel,  th {color: #000000 !IMPORTANT ;background-color: #c8e6c9 !IMPORTANT ;border: 1px solid #4caf50 !IMPORTANT ;}
#
# </style>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/pivottable/2.23.0/pivot.min.css" type="text/css">
# </head>
# <body>
# <div id="row_139686963672960" style="font-size:inherit;font-family:inherit;box-sizing:border-box;width:100%;justify-content:middle" class="cssdivnoborder row"><div id="col_139686963674080" style="display:inline-block;justify-content:middle" class="col col-6"><div id="pivottable_139686963575664" style="font-size:inherit;font-family:inherit;box-sizing:border-box;width:100%;display:block" class="cssdivnoborder pvtTable"></div></div><div id="col_139686963674248" style="display:inline-block;justify-content:middle;padding-left:10px" class="col col-6"><div id="pivottable_139686963618088" style="font-size:inherit;font-family:inherit;box-sizing:border-box;width:100%;display:block" class="cssdivnoborder pvtTable"></div></div></div>
# <script>
# require.config({ paths:{pivot: 'https://cdnjs.cloudflare.com/ajax/libs/pivottable/2.23.0/pivot.min', popper: 'https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.6/umd/popper.min'}});
# require(['popper', 'pivot'], function (popper, pivot) { function PivotTable(htmlObj, data, options){
#       if (options.showUI){$(htmlObj).pivotUI(data, options)}
#       else {$(htmlObj).pivot(data, options)}
#       };PivotTable(document.getElementById('pivottable_139686963575664'), [{"name": "C", "type": "code", "rating": 17.07, "change": 12.82}, {"name": "Java", "type": "code", "rating": 16.28, "change": 0.28}, {"name": "Python", "type": "script", "rating": 9.12, "change": 1.29}, {"name": "C++", "type": "code", "rating": 6.13, "change": -1.97}, {"name": "C#", "type": "code", "rating": 4.29, "change": 0.3}, {"name": "Visual Basic", "type": "script", "rating": 4.18, "change": -1.01}, {"name": "JavaScript", "type": "script", "rating": 2.68, "change": -0.01}, {"name": "PHP", "type": "script", "rating": 2.49, "change": 0}, {"name": "SQL", "type": "script", "rating": 2.09, "change": -0.47}, {"name": "R", "type": "script", "rating": 1.85, "change": 0.9}], {cols: ["type"],rows: ["name"],aggregator: $.pivotUtilities.aggregators["Sum"](["rating"]),aggregatorName: "sum"});PivotTable(document.getElementById('pivottable_139686963618088'), [{"name": "C", "type": "code", "rating": 17.07, "change": 12.82}, {"name": "Java", "type": "code", "rating": 16.28, "change": 0.28}, {"name": "Python", "type": "script", "rating": 9.12, "change": 1.29}, {"name": "C++", "type": "code", "rating": 6.13, "change": -1.97}, {"name": "C#", "type": "code", "rating": 4.29, "change": 0.3}, {"name": "Visual Basic", "type": "script", "rating": 4.18, "change": -1.01}, {"name": "JavaScript", "type": "script", "rating": 2.68, "change": -0.01}, {"name": "PHP", "type": "script", "rating": 2.49, "change": 0}, {"name": "SQL", "type": "script", "rating": 2.09, "change": -0.47}, {"name": "R", "type": "script", "rating": 1.85, "change": 0.9}], {cols: ["type"],rows: ["name"],aggregator: $.pivotUtilities.aggregators["Sum"](["rating"]),aggregatorName: "sum"}) })
# </script>
# <body>
