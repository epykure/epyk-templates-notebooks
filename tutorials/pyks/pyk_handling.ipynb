# %%
import sys, subprocess
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '--upgrade','epyk'])
# Out:
# 0

# %% [markdown]
# # Pyk Reports
# A Pyk report is a report that allows you to specify objects to export for another reports to use.
# This is especially useful to prevent you to duplicate code that is fairly reusable.
# With this method you can reuse components that you're particularly proud of or even things you want to share for other people to leverage on !
# ## 2-Steps Process
# To take advantage of this feature you simply need to declare within your reports the objects you would like to be reusable.
# This is very similar to the Node.js export/require mechanisms.
#
# ### Exports
#
# First - Within a report you've created you can define functions/epyk components you would like to share.
# For instance we've create a pyk_report.py script that looks like this:

# %%
from epyk.core.Page import Report
rptObj = Report()

button = rptObj.ui.buttons.button('This is button')
imp = rptObj.ui.buttons.important('This is an important button')

rptObj.outs.jupyter()
# Out:
# <head>
# <style>
#     .cssbuttonbasic_button_140524492367888 {font-weight: bold ;padding: 2px 20px ;margin: 2px 0 2px 0 ;text-decoration: none ;border-radius: 4px ;white-space: nowrap ;display: inline-block ;line-height: 30px ;-webkit-appearance: none ;-moz-appearance: none ;border: 1px solid #bdbdbd ;color: #1b5e20 ;background-color: #FFFFFF ;}
# .cssbuttonbasic_button_140524492367888:hover {text-decoration: none ;cursor: pointer ;background-color: #e8f5e9 ;color: #1b5e20 ;}
# .cssbuttonbasic_button_140524492367888:focus {outline: 0 ;}
# .cssbuttonbasic_button_140524492367888:disabled {cursor: none ;background-color: #1b5e20 ;color: #43a047 ;font-style: italic ;}
# .cssbuttonbasic_button_140524492340304 {font-weight: bold ;padding: 2px 20px ;margin: 2px 0 2px 0 ;text-decoration: none ;border-radius: 4px ;white-space: nowrap ;display: inline-block ;line-height: 30px ;-webkit-appearance: none ;-moz-appearance: none ;border: 1px solid #bdbdbd ;color: #1b5e20 ;background-color: #FFFFFF ;}
# .cssbuttonbasic_button_140524492340304:hover {text-decoration: none ;cursor: pointer ;background-color: #e8f5e9 ;color: #1b5e20 ;}
# .cssbuttonbasic_button_140524492340304:focus {outline: 0 ;}
# .cssbuttonbasic_button_140524492340304:disabled {cursor: none ;background-color: #1b5e20 ;color: #43a047 ;font-style: italic ;}
# .cssbuttonimportant {font-weight: bold ;padding: 2px 20px ;margin: 2px 0 2px 0 ;text-decoration: none ;border-radius: 4px ;white-space: nowrap ;display: inline-block ;line-height: 30px ;-webkit-appearance: none ;-moz-appearance: none ;border: 1px solid ;color: #FFFFFF ;background-color: #2e7d32 ;}
# .cssbuttonimportant:hover {text-decoration: none ;cursor: pointer ;background-color: #1b5e20 ;color: #FFFFFF ;}
# .cssbuttonimportant:focus {outline: 0 ;}
# .cssbuttonimportant:disabled {cursor: none ;background-color: #1b5e20 ;color: #43a047 ;font-style: italic ;}
#
# </style>
#
# </head>
# <body>
# <button name data-count="0" id="button_140524492367888" style="font-size:12px" class="cssbuttonbasic_button_140524492367888">This is button</button>
# <button name data-count="0" id="button_140524492340304" style="font-size:12px" class="cssbuttonbasic_button_140524492340304 cssbuttonimportant">This is an important button</button>
# <script>
# require.config({ paths:{}});
#
# </script>
# <body>

# %% [markdown]
# For now this script left like this wouldn't be able to share anything with another report. To remedy that you just need to add those lines:
# ```
# from epyk.core.py import Pyk
# Pyk.exports({'button': button, 'imp': imp})
# ```
#
# Here we simple tell Epyk that we wish to ```exports``` our button and imp components using a dictionary. The key of the dictionaries are simply the aliases we wish to give our object. These aliases will be used to then retreive the object on the consumer side.

# %%
from epyk.core.Page import Report
from epyk.core.py import Pyk
rptObj = Report()


button = rptObj.ui.buttons.button('This is button')
imp = rptObj.ui.buttons.important('This is an important button')

Pyk.exports({'button': button, 'imp': imp})
rptObj.outs.jupyter()
# Out:
# <head>
# <style>
#     .cssbuttonbasic_button_140524492212432 {font-weight: bold ;padding: 2px 20px ;margin: 2px 0 2px 0 ;text-decoration: none ;border-radius: 4px ;white-space: nowrap ;display: inline-block ;line-height: 30px ;-webkit-appearance: none ;-moz-appearance: none ;border: 1px solid #bdbdbd ;color: #1b5e20 ;background-color: #FFFFFF ;}
# .cssbuttonbasic_button_140524492212432:hover {text-decoration: none ;cursor: pointer ;background-color: #e8f5e9 ;color: #1b5e20 ;}
# .cssbuttonbasic_button_140524492212432:focus {outline: 0 ;}
# .cssbuttonbasic_button_140524492212432:disabled {cursor: none ;background-color: #1b5e20 ;color: #43a047 ;font-style: italic ;}
# .cssbuttonbasic_button_140524493013776 {font-weight: bold ;padding: 2px 20px ;margin: 2px 0 2px 0 ;text-decoration: none ;border-radius: 4px ;white-space: nowrap ;display: inline-block ;line-height: 30px ;-webkit-appearance: none ;-moz-appearance: none ;border: 1px solid #bdbdbd ;color: #1b5e20 ;background-color: #FFFFFF ;}
# .cssbuttonbasic_button_140524493013776:hover {text-decoration: none ;cursor: pointer ;background-color: #e8f5e9 ;color: #1b5e20 ;}
# .cssbuttonbasic_button_140524493013776:focus {outline: 0 ;}
# .cssbuttonbasic_button_140524493013776:disabled {cursor: none ;background-color: #1b5e20 ;color: #43a047 ;font-style: italic ;}
# .cssbuttonimportant {font-weight: bold ;padding: 2px 20px ;margin: 2px 0 2px 0 ;text-decoration: none ;border-radius: 4px ;white-space: nowrap ;display: inline-block ;line-height: 30px ;-webkit-appearance: none ;-moz-appearance: none ;border: 1px solid ;color: #FFFFFF ;background-color: #2e7d32 ;}
# .cssbuttonimportant:hover {text-decoration: none ;cursor: pointer ;background-color: #1b5e20 ;color: #FFFFFF ;}
# .cssbuttonimportant:focus {outline: 0 ;}
# .cssbuttonimportant:disabled {cursor: none ;background-color: #1b5e20 ;color: #43a047 ;font-style: italic ;}
#
# </style>
#
# </head>
# <body>
# <button name data-count="0" id="button_140524492212432" style="font-size:12px" class="cssbuttonbasic_button_140524492212432">This is button</button>
# <button name data-count="0" id="button_140524493013776" style="font-size:12px" class="cssbuttonbasic_button_140524493013776 cssbuttonimportant">This is an important button</button>
# <script>
# require.config({ paths:{}});
#
# </script>
# <body>

# %% [markdown]
# Here we have created our output for jupyter AND we specified that some of our components were going to be reused elsewhere. We could have very well skipped the ```rptObj.outs.jupyter()```. But we wanted to show that both method were not exclusive.

# %% [markdown]
# Now both ```button``` and ```imp``` would be available to be called from another report
# ### Imports
#
# Now to be able to use objects coming from a Pyk, we will see what needs to be done on the consumer side.
#
# First we need to specify where we're going to need to pick up object. This is done through the ```requires```  method:
#
# ```
# from epyk.core.Page import Report
# pyk_rpt = Pyk.requires(r'<path>pyk_report.py')
# ```
# or
# ```pyk_rpt = Pyk.requires('pyk_report') #if pyk report is on Pypi```
#
# The ```requires``` method will work for two cases:
# - given an absolute path to a python script
# - given a package name, if the package is already installed for the interpreter it will work automatically, if not you will either need to install it prealably or specify the ```autoinstall``` argument to ```True```
#
# Finally to add the imported object to your report you will need to call the ```register``` function at the moment you want to add your component within the report.
#
# ```rpt_obj.register(pyk_rpt.button)```
#
# This accept accept a single components as well as a list of those

# %%
import os
from epyk.core.py import Pyk
from epyk.core.Page import Report

pyk_rpt = Pyk.requires(os.path.abspath('pyk_report.py'))


rptObj = Report()

rptObj.ui.text("Here we have a text followed by a normal button")

rptObj.register(pyk_rpt.button)

rptObj.ui.text("Then we have an important button")

rptObj.register(pyk_rpt.imp)

rptObj.outs.jupyter()
# Out:
# <head>
# <style>
#     .cssdivnoborder {margin: 0 ;clear: both ;padding: 0 ;border: 0 ;}
# .cssbuttonbasic_button_140261667345104 {font-weight: bold ;padding: 2px 20px ;margin: 2px 0 2px 0 ;text-decoration: none ;border-radius: 4px ;white-space: nowrap ;display: inline-block ;line-height: 30px ;-webkit-appearance: none ;-moz-appearance: none ;border: 1px solid #bdbdbd ;color: #1b5e20 ;background-color: #FFFFFF ;}
# .cssbuttonbasic_button_140261667345104:hover {text-decoration: none ;cursor: pointer ;background-color: #e8f5e9 ;color: #1b5e20 ;}
# .cssbuttonbasic_button_140261667345104:focus {outline: 0 ;}
# .cssbuttonbasic_button_140261667345104:disabled {cursor: none ;background-color: #1b5e20 ;color: #43a047 ;font-style: italic ;}
# .cssbuttonbasic_button_140261667346384 {font-weight: bold ;padding: 2px 20px ;margin: 2px 0 2px 0 ;text-decoration: none ;border-radius: 4px ;white-space: nowrap ;display: inline-block ;line-height: 30px ;-webkit-appearance: none ;-moz-appearance: none ;border: 1px solid #bdbdbd ;color: #1b5e20 ;background-color: #FFFFFF ;}
# .cssbuttonbasic_button_140261667346384:hover {text-decoration: none ;cursor: pointer ;background-color: #e8f5e9 ;color: #1b5e20 ;}
# .cssbuttonbasic_button_140261667346384:focus {outline: 0 ;}
# .cssbuttonbasic_button_140261667346384:disabled {cursor: none ;background-color: #1b5e20 ;color: #43a047 ;font-style: italic ;}
# .cssbuttonimportant {font-weight: bold ;padding: 2px 20px ;margin: 2px 0 2px 0 ;text-decoration: none ;border-radius: 4px ;white-space: nowrap ;display: inline-block ;line-height: 30px ;-webkit-appearance: none ;-moz-appearance: none ;border: 1px solid ;color: #FFFFFF ;background-color: #2e7d32 ;}
# .cssbuttonimportant:hover {text-decoration: none ;cursor: pointer ;background-color: #1b5e20 ;color: #FFFFFF ;}
# .cssbuttonimportant:focus {outline: 0 ;}
# .cssbuttonimportant:disabled {cursor: none ;background-color: #1b5e20 ;color: #43a047 ;font-style: italic ;}
#
# </style>
#
# </head>
# <body>
# <div id="text_140261665207440" style="font-size:inherit;font-family:inherit;box-sizing:border-box;width:auto;text-align:left" class="cssdivnoborder">Here we have a text followed by a normal button</div>
# <button data-count="0" id="button_140261667345104" style="font-size:12px" class="cssbuttonbasic_button_140261667345104">This is button</button>
# <div id="text_140261665196304" style="font-size:inherit;font-family:inherit;box-sizing:border-box;width:auto;text-align:left" class="cssdivnoborder">Then we have an import button</div>
# <button data-count="0" id="button_140261667346384" style="font-size:12px" class="cssbuttonbasic_button_140261667346384 cssbuttonimportant">This is an important button</button>
# <script>
# require.config({ paths:{}});
#
# </script>
# <body>

# %% [markdown]
# You now have a mixture of object defined from your own report and object imported from another one !!
