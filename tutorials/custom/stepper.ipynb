# %% [markdown]
# <div style="float:left;margin:0 10px 10px 0" markdown="1">
#     <a href="../../index.ipynb">
#         <img src="../../static/images/epyklogo_whole_small.png">
#     </a>
# </div>

# %% [markdown]
# # Custom Steps
#
# It is possible to create in your environment bespoke steps for the stepper component by using the add_shape function. This will allow you to define your bespoke shape dom object (this should be a SVG component, please have a look here for more details about [SVG](https://www.w3schools.com/graphics/svg_circle.asp)).
#
# A bespoke step should follow the below rules:
# - A **SVG shape** variable
#
#
# ## Basic example
#
# The below example will create oval steps.

# %%
from epyk.core.Page import Report

# Create a basic report object
rptObj = Report()

# Stepper data
records = []
for i in range(6):
  records.append({'status': 'success', "tooltip": "test", 'value': 'test', 'title': 'Ok %s' % i, 'label': 'Label %s' % i},)

# Create a stepper
sp = rptObj.ui.stepper(records)
sp.options.line = False

sp.add_shape("signal", '''
var shape = document.createElementNS(svgns, 'ellipse');
shape.setAttribute('stroke', options.backgrounds[status]);
shape.setAttribute('stroke-width', 1);
shape.setAttribute('cx', width / options.circle_factor );
shape.setAttribute('cy', height / options.circle_factor );
shape.setAttribute('rx', width / options.circle_factor );
shape.setAttribute('ry', height / options.circle_factor );
''')


rptObj.outs.jupyter()
# Out:
# <head>
# <style>
#     .cssdivnoborder_stepper_1738286693296 {margin: 0 ;clear: both ;padding: 0 ;border: 0 ;}
# @media only screen and (max-width: 600px) {
#   .cssdivstepper li {float: None; width: 100%; }
#   .cssdivstepper li line {stroke-width: 0; }
#   .cssdivstepper li [name=label] {width: 100%!IMPORTANT; }
# }
# .cssdivstepper li {float: left ;text-align: center ;}
#
# </style>
#
# </head>
# <body>
# <ul id="stepper_1738286693296" style="font-size:inherit;font-family:inherit;box-sizing:border-box;list-style-type:none;width:100%;color:#000000;margin:0;display:block" class="cssdivnoborder_stepper_1738286693296 cssdivstepper"></ul>
# <script>
# require.config({ paths:{}});
# function signal(htmlObj, options, step){
#         var width = options.svg_style.width; var height = options.svg_style.height;
#         var svgns = 'http://www.w3.org/2000/svg';
#         var svg = document.createElementNS(svgns, 'svg');
#         var defs = document.createElementNS(svgns, 'defs');
# ...

# %% [markdown]
# ## Advanced example
#
# It is also possible to create more complex shapes with for example a special content.
# From this it is possible to use the step variable whihch is basically what is defined in the various record in the records Python variable.
#
# Thus by adding extra fields to the Python object it is possible to add more details to your step object.

# %%
from epyk.core.Page import Report

# Create a basic report object
rptObj = Report()

# Stepper data
records = []
for i in range(6):
  records.append({'status': 'success', "tooltip": "test", 'value': 'test', 'title': 'Ok %s' % i, 'label': 'Label %s' % i},)

# Create a stepper
sp = rptObj.ui.stepper(records)
sp.options.line = False

sp.add_shape("signal", '''
var shape = document.createElementNS(svgns, 'circle');
shape.setAttribute('stroke', options.backgrounds[status]);
shape.setAttribute('stroke-width', 1);
shape.setAttribute('cx', width / (options.circle_factor * 2) );
shape.setAttribute('cy', height / options.circle_factor  );
shape.setAttribute('r', height / (options.circle_factor * 2) );


var newText = document.createElementNS("http://www.w3.org/2000/svg", "text");
newText.setAttributeNS(null, 'x', (width / 2) +'px');
newText.setAttributeNS(null, 'y', (height / 2) + 5 +'px');
var textNode = document.createTextNode(step.label);
newText.appendChild(textNode);

svg.appendChild(newText)

''')

rptObj.ui.button("Test").click([
  sp.dom[0].rectangle(),
  sp.dom[1].triangle(),
  sp.dom[2].circle(),
  sp.dom[3].arrow(),
])

rptObj.outs.jupyter()
# Out:
# <head>
# <style>
#     .cssdivnoborder_stepper_1738286661104 {margin: 0 ;clear: both ;padding: 0 ;border: 0 ;}
# @media only screen and (max-width: 600px) {
#   .cssdivstepper li {float: None; width: 100%; }
#   .cssdivstepper li line {stroke-width: 0; }
#   .cssdivstepper li [name=label] {width: 100%!IMPORTANT; }
# }
# .cssdivstepper li {float: left ;text-align: center ;}
# .cssbuttonbasic_button_1738286513264 {font-weight: bold ;padding: 2px 20px ;margin: 2px 0 2px 0 ;text-decoration: none ;border-radius: 4px ;white-space: nowrap ;display: inline-block ;line-height: 30px ;-webkit-appearance: none ;-moz-appearance: none ;border: 1px solid #bdbdbd ;color: #1b5e20 ;background-color: #FFFFFF ;}
# .cssbuttonbasic_button_1738286513264:hover {text-decoration: none ;cursor: pointer ;background-color: #e8f5e9 ;color: #1b5e20 ;}
# .cssbuttonbasic_button_1738286513264:focus {outline: 0 ;}
# ...

# %% [markdown]
# [Go back to the tutorials page](../../tutorials.ipynb)
#
# <hr>
# Do not forget that this is a collaborative framework so do not hesitate to give feedbacks and like the different repository to get more visbility.
#
# If you believe your bespoke shape should be included to the core library do not hesitate to create a pull request !
#
# Also any help is more than welcome !
