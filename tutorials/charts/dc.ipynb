# %% [markdown]
# <div style="float:left;margin:0 10px 10px 0" markdown="1">
#     <a href="index.ipynb">
#         <img src="./../../static/images/epyklogo_whole_small.png">
#     </a>
# </div>

# %% [markdown]
# # DC Cross Filter
#
#
# Chart from DC [component](00_components.ipynb) in Epyk will be using the property dc from the ui.charts property.
#
# <i>the ui entry point will give you access to all the registered components.
# Different flavour of buttons are available in the framework.</i>
#
# ## Available Charts
#
# - [Line Chart](./dc/dc_line.ipynb)
# - [Series Chart](dc/dc_series.ipynb)
# - [Scatter Chart](dc/dc_scatter.ipynb)
# - [Step Chart](dc/dc_step.ipynb)
# - [Bar Chart](dc/dc_bar.ipynb)
# - [Horizontal Bar Chart](dc/dc_horizontal_bar.ipynb)
# - [Pie Chart](dc/dc_pie.ipynb)
# - [Sunburst Chart](dc/dc_sunburst.ipynb)
# - [Bubble Chart](dc/dc_bubble.ipynb)
#
# ## Example of Charts

# %%
from epyk.core.Page import Report
from epyk.tests import data_urls

rptObj = Report()
data_rest = rptObj.py.requests.csv(data_urls.PLOTLY_APPLE_PRICES)

ts = rptObj.ui.charts.dc.line(data_rest, y_columns=['AAPL.Open'], x_axis="Date")

rptObj.outs.jupyter()
# Out:
# <head>
# <style>
#     .cssdivnoborder {margin: 0 ;clear: both ;padding: 0 ;border: 0 ;}
#
# </style>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/dc/3.2.1/dc.min.css" type="text/css">
# </head>
# <body>
# <div id="chartseries_2022760854576" style="font-size:inherit;font-family:inherit;box-sizing:border-box;width:100%;height:330px;margin:10px 0" class="cssdivnoborder"></div>
# <div id="chartseries_2022760854576" style="font-size:inherit;font-family:inherit;box-sizing:border-box;width:100%;height:330px;margin:10px 0" class="cssdivnoborder"></div>
# <script>
# require.config({ paths:{crossfilter: 'https://cdnjs.cloudflare.com/ajax/libs/crossfilter/1.3.12/crossfilter.min', d3: 'https://cdnjs.cloudflare.com/ajax/libs/d3/5.9.7/d3.min', dc: 'https://cdnjs.cloudflare.com/ajax/libs/dc/3.2.1/dc.min'}});
# ...

# %% [markdown]
# <a href="charts.ipynb" target="_self">Go back to the Chart Home page</a>
# <hr>
# Do not forget that this is a collaborative framework so do not hesitate to give feedbacks and like the different repository to get more visbility.
#
# Also any help is more than welcome !
