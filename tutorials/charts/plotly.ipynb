# %% [markdown]
# <div style="float:left;margin:0 10px 10px 0" markdown="1">
#     <a href="index.ipynb">
#         <img src="./../../static/images/epyklogo_whole_small.png">
#     </a>
# </div>

# %% [markdown]
# # Plotly
#
#
# Chart from Plotly.JS [component](00_components.ipynb) in Epyk will be using the property plotly from the ui.charts property.
#
# <i>the ui entry point will give you access to all the registered components.
# Different flavour of buttons are available in the framework.</i>
#
# ## Available Charts
#
# ### 2D Charts
#
# - [Line Chart](./plotly/plotly_line.ipynb)
# - [Bar Chart](./plotly/plotly_bar.ipynb)
# - [Horizontal Bar Chart](./plotly/plotly_h_bar.ipynb)
# - [Scatter Chart](./plotly/plotly_scatter.ipynb))
# - [Timeseries Chart](./plotly/plotly_timseries.ipynb)
# - [Scatter GL Chart](./plotly/plotly_scattergl.ipynb)
# - [Historgram Chart](./plotly/plotly_histogram.ipynb)
# - [Pie Chart](./plotly/plotly_pie.ipynb)
# - [Area Chart](./plotly/plotly_area.ipynb)
# - [Bubble Chart](./plotly/plotly_bubble.ipynb)
#
# ### Indicators
# - [Number](./plotly/plotly_number.ipynb)
#
#
# ## Example of Charts

# %%
from epyk.core.Page import Report
from epyk.tests import data_urls

rptObj = Report()

data = rptObj.py.requests.csv(data_urls.PLOTLY_WEBGL_POLAR)
sc = rptObj.ui.charts.plotly.scatterpolar(data, r_columns=['trial_1_r'], theta_axis='trial_1_theta')

rptObj.outs.jupyter()
# Out:
# <head>
# <style>
#     .cssdivnoborder {margin: 0 ;clear: both ;padding: 0 ;border: 0 ;}
#
# </style>
#
# </head>
# <body>
# <div id="scatterpolar_2411708615312" style="font-size:inherit;font-family:inherit;box-sizing:border-box;width:100%;height:330px" class="cssdivnoborder"></div>
# <script>
# var jQuery = $;
# require.config({ paths:{d3: 'https://cdnjs.cloudflare.com/ajax/libs/d3/5.9.7/d3.min', Plotly: 'https://cdnjs.cloudflare.com/ajax/libs/plotly.js/1.51.1/plotly.min'}});
# require(['d3'], function (d3) { require(['Plotly'], function (Plotly) { Plotly.newPlot("scatterpolar_2411708615312", [{r: ["6.804985785", "3.389596011", "5.381472111", "8.059540219", "5.318229228", "2.985099936", "1.966587002", "6.769265408", "4.073401899", "6.504371825", "7.556369819", "4.047456094", "7.386662496", "5.413624737", "7.470716531", "7.982110217", "4.73781408", "4.206453043", "5.478604805", "4.824520281", "5.59960061", "6.866795217", "3.085671366", "7.771810943", "3.687794435", "5.360356685", "5.140446739", "6.045445681", "6.83392094", "3.620769463", "3.989430583", "5.3118245", "4.60821348", "6.640584716", "3.055188854", "7.492564164", "5.485078178", "3.897794997", "5.976245114", "5.447061561", "5.377034117", "4.690805788", "4.711640491", "3.629919329", "5.957668076", "5.357121284", "3.849235283", "6.250507136", "7.122243357", "3.399404234", "3.510556672", "4.100997604", "4.0963821", "6.233583075", "3.939488527", "3.925445077", "6.118132501", "3.940450346", "7.583015573", "3.513202145"], theta: ["-30.35294436", "-25.61145985", "-12.42522745", "13.96138052", "-4.950932841", "-25.69227419", "12.46876416", "-4.913764107", "-10.96738029", "30.81419405", "2.474959431", "17.97554375", "0.771130593", "6.137488486", "-14.45196357", "28.18453411", "12.53868007", "-8.983230337", "5.231285165", "-64.48900254", "11.35748668", "3.454074792", "13.92434661", "-25.36400205", "-16.81800639", "-10.26005103", "-13.21213413", "2.579338865", "8.717574966", "-10.67549872", "-2.926366013", "25.19588075", "40.59032932", "-9.12143363", "-24.29736238", "-3.176944506", "10.85049842", "-31.33205975", "4.849567462", "15.04827695", "3.295104699", "-6.197091873", "-8.778574136", "29.54917412", "-5.137448793", "23.02686049", "-6.634816578", "2.755014992", "21.73325011", "-24.81699496", "-7.830547063", "28.32579621", "12.30097747", "-21.56315724", "-19.33551628", "26.14644317", "-1.706071203", "16.0717237", "2.053266303", "-5.097911612"], type: "scatterpolar", mode: "line", fill: "toself", marker: {color: null}}], {}, {}) }) })
# </script>
# <body>

# %% [markdown]
# <hr>
# Do not forget that this is a collaborative framework so do not hesitate to give feedbacks and like the different repository to get more visbility.
#
# Also any help is more than welcome !

# %%
from epyk.core.Page import Report

rptObj = Report()

line = rptObj.ui.charts.plotly.line()
line.data.x = [19097, 18601, 15595, 13546, 12026, 7434, 5419]
line.data.y = [43, 47, 56, 80, 86, 93, 80]
line.data.mode = 'markers'
line.data.type = 'scatter'
line.layout.no_grid()
line.layout.no_background()

rptObj.outs.jupyter()
# Out:
# <head>
# <style>
#     .cssdivnoborder {margin: 0 ;clear: both ;padding: 0 ;border: 0 ;}
#
# </style>
#
# </head>
# <body>
# <div id="line_2411727448432" style="font-size:inherit;font-family:inherit;box-sizing:border-box;width:100%;height:330px" class="cssdivnoborder"></div>
# <script>
# var jQuery = $;
# require.config({ paths:{d3: 'https://cdnjs.cloudflare.com/ajax/libs/d3/5.9.7/d3.min', Plotly: 'https://cdnjs.cloudflare.com/ajax/libs/plotly.js/1.51.1/plotly.min'}});
# require(['d3'], function (d3) { require(['Plotly'], function (Plotly) { Plotly.newPlot("line_2411727448432", [{mode: "markers", x: [19097, 18601, 15595, 13546, 12026, 7434, 5419], y: [43, 47, 56, 80, 86, 93, 80], type: "scatter"}], {xaxis: {showgrid: false, showline: false, showticklabels: false}, yaxis: {showgrid: false, showline: false, showticklabels: false}, paper_bgcolor: "rgba(0,0,0,0)", plot_bgcolor: "rgba(0,0,0,0)"}, {responsive: true}) }) })
# </script>
# <body>

# %%
from epyk.core.Page import Report

rptObj = Report()
bar = rptObj.ui.charts.plotly.bar()
bar.layout.no_background()
bar.layout.grid_colors('grey')
bar.layout.axis_colors('white')
bar.data.x = ['giraffes', 'orangutans', 'monkeys']
bar.data.y = [12, 18, 29]
bar.data.name = 'LA Zoo'
bar.data.type = 'bar'
bar.layout.barmode = 'stack'


rptObj.outs.jupyter()
# Out:
# <head>
# <style>
#     .cssdivnoborder {margin: 0 ;clear: both ;padding: 0 ;border: 0 ;}
#
# </style>
#
# </head>
# <body>
# <div id="bar_2411726792736" style="font-size:inherit;font-family:inherit;box-sizing:border-box;width:100%;height:330px" class="cssdivnoborder"></div>
# <script>
# var jQuery = $;
# require.config({ paths:{d3: 'https://cdnjs.cloudflare.com/ajax/libs/d3/5.9.7/d3.min', Plotly: 'https://cdnjs.cloudflare.com/ajax/libs/plotly.js/1.51.1/plotly.min'}});
# require(['d3'], function (d3) { require(['Plotly'], function (Plotly) { Plotly.newPlot("bar_2411726792736", [{type: "bar", x: ["giraffes", "orangutans", "monkeys"], y: [12, 18, 29], name: "LA Zoo"}], {xaxis: {tickfont: {color: "white"}, titlefont: {color: "white"}, gridcolor: "grey"}, yaxis: {tickfont: {color: "white"}, titlefont: {color: "white"}, gridcolor: "grey"}, paper_bgcolor: "rgba(0,0,0,0)", plot_bgcolor: "rgba(0,0,0,0)", barmode: "stack"}, {}) }) })
# </script>
# <body>

# %%
from epyk.core.Page import Report
from epyk.tests import data_urls

rptObj = Report()

data = rptObj.py.requests.csv(data_urls.PLOTLY_APPLE_PRICES)

ts = rptObj.ui.charts.plotly.timeseries(data, y_columns=['AAPL.Open', 'AAPL.High', 'AAPL.Low'], x_axis="Date")

rptObj.outs.jupyter()
# Out:
# <head>
# <style>
#     .cssdivnoborder {margin: 0 ;clear: both ;padding: 0 ;border: 0 ;}
#
# </style>
#
# </head>
# <body>
# <div id="line_2411726807248" style="font-size:inherit;font-family:inherit;box-sizing:border-box;width:100%;height:330px" class="cssdivnoborder"></div>
# <script>
# var jQuery = $;
# require.config({ paths:{d3: 'https://cdnjs.cloudflare.com/ajax/libs/d3/5.9.7/d3.min', Plotly: 'https://cdnjs.cloudflare.com/ajax/libs/plotly.js/1.51.1/plotly.min'}});
# require(['d3'], function (d3) { require(['Plotly'], function (Plotly) { Plotly.newPlot("line_2411726807248", [{x: ["2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-23", "2015-02-24", "2015-02-25", "2015-02-26", "2015-02-27", "2015-03-02", "2015-03-03", "2015-03-04", "2015-03-05", "2015-03-06", "2015-03-09", "2015-03-10", "2015-03-11", "2015-03-12", "2015-03-13", "2015-03-16", "2015-03-17", "2015-03-18", "2015-03-19", "2015-03-20", "2015-03-23", "2015-03-24", "2015-03-25", "2015-03-26", "2015-03-27", "2015-03-30", "2015-03-31", "2015-04-01", "2015-04-02", "2015-04-06", "2015-04-07", "2015-04-08", "2015-04-09", "2015-04-10", "2015-04-13", "2015-04-14", "2015-04-15", "2015-04-16", "2015-04-17", "2015-04-20", "2015-04-21", "2015-04-22", "2015-04-23", "2015-04-24", "2015-04-27", "2015-04-28", "2015-04-29", "2015-04-30", "2015-05-01", "2015-05-04", "2015-05-05", "2015-05-06", "2015-05-07", "2015-05-08", "2015-05-11", "2015-05-12", "2015-05-13", "2015-05-14", "2015-05-15", "2015-05-18", "2015-05-19", "2015-05-20", "2015-05-21", "2015-05-22", "2015-05-26", "2015-05-27", "2015-05-28", "2015-05-29", "2015-06-01", "2015-06-02", "2015-06-03", "2015-06-04", "2015-06-05", "2015-06-08", "2015-06-09", "2015-06-10", "2015-06-11", "2015-06-12", "2015-06-15", "2015-06-16", "2015-06-17", "2015-06-18", "2015-06-19", "2015-06-22", "2015-06-23", "2015-06-24", "2015-06-25", "2015-06-26", "2015-06-29", "2015-06-30", "2015-07-01", "2015-07-02", "2015-07-06", "2015-07-07", "2015-07-08", "2015-07-09", "2015-07-10", "2015-07-13", "2015-07-14", "2015-07-15", "2015-07-16", "2015-07-17", "2015-07-20", "2015-07-21", "2015-07-22", "2015-07-23", "2015-07-24", "2015-07-27", "2015-07-28", "2015-07-29", "2015-07-30", "2015-07-31", "2015-08-03", "2015-08-04", "2015-08-05", "2015-08-06", "2015-08-07", "2015-08-10", "2015-08-11", "2015-08-12", "2015-08-13", "2015-08-14", "2015-08-17", "2015-08-18", "2015-08-19", "2015-08-20", "2015-08-21", "2015-08-24", "2015-08-25", "2015-08-26", "2015-08-27", "2015-08-28", "2015-08-31", "2015-09-01", "2015-09-02", "2015-09-03", "2015-09-04", "2015-09-08", "2015-09-09", "2015-09-10", "2015-09-11", "2015-09-14", "2015-09-15", "2015-09-16", "2015-09-17", "2015-09-18", "2015-09-21", "2015-09-22", "2015-09-23", "2015-09-24", "2015-09-25", "2015-09-28", "2015-09-29", "2015-09-30", "2015-10-01", "2015-10-02", "2015-10-05", "2015-10-06", "2015-10-07", "2015-10-08", "2015-10-09", "2015-10-12", "2015-10-13", "2015-10-14", "2015-10-15", "2015-10-16", "2015-10-19", "2015-10-20", "2015-10-21", "2015-10-22", "2015-10-23", "2015-10-26", "2015-10-27", "2015-10-28", "2015-10-29", "2015-10-30", "2015-11-02", "2015-11-03", "2015-11-04", "2015-11-05", "2015-11-06", "2015-11-09", "2015-11-10", "2015-11-11", "2015-11-12", "2015-11-13", "2015-11-16", "2015-11-17", "2015-11-18", "2015-11-19", "2015-11-20", "2015-11-23", "2015-11-24", "2015-11-25", "2015-11-27", "2015-11-30", "2015-12-01", "2015-12-02", "2015-12-03", "2015-12-04", "2015-12-07", "2015-12-08", "2015-12-09", "2015-12-10", "2015-12-11", "2015-12-14", "2015-12-15", "2015-12-16", "2015-12-17", "2015-12-18", "2015-12-21", "2015-12-22", "2015-12-23", "2015-12-24", "2015-12-28", "2015-12-29", "2015-12-30", "2015-12-31", "2016-01-04", "2016-01-05", "2016-01-06", "2016-01-07", "2016-01-08", "2016-01-11", "2016-01-12", "2016-01-13", "2016-01-14", "2016-01-15", "2016-01-19", "2016-01-20", "2016-01-21", "2016-01-22", "2016-01-25", "2016-01-26", "2016-01-27", "2016-01-28", "2016-01-29", "2016-02-01", "2016-02-02", "2016-02-03", "2016-02-04", "2016-02-05", "2016-02-08", "2016-02-09", "2016-02-10", "2016-02-11", "2016-02-12", "2016-02-16", "2016-02-17", "2016-02-18", "2016-02-19", "2016-02-22", "2016-02-23", "2016-02-24", "2016-02-25", "2016-02-26", "2016-02-29", "2016-03-01", "2016-03-02", "2016-03-03", "2016-03-04", "2016-03-07", "2016-03-08", "2016-03-09", "2016-03-10", "2016-03-11", "2016-03-14", "2016-03-15", "2016-03-16", "2016-03-17", "2016-03-18", "2016-03-21", "2016-03-22", "2016-0 ...

# %% [markdown]
# <a href="charts.ipynb" target="_self">Go back to the Chart Home page</a>
# <hr>
# Do not forget that this is a collaborative framework so do not hesitate to give feedbacks and like the different repository to get more visbility.
#
# Also any help is more than welcome !
