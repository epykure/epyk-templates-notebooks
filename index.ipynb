# %% [markdown]
# <div style="margin:0 10px 10px 0" markdown="1">
#     <a href="index.ipynb">
#         <img src="static/images/logo.png">
#     </a>
# </div>

# %% [markdown]
# <center><b>Be a fullstack developer in Python!</b></center>
#
# ## Quickstart
# Get started with a [5-min introduction to Epyk](quickstart.ipynb).
#
# ## First Version out now!
#
# An easy to use Python Framework using JavaScript modules.
# You can fin the reposity on [Github](https://github.com/epykure/epyk-ui) and the latest version on [pypi](https://pypi.org/project/epyk/).
#
# We need your support so please do not hesitate to like the projects !
#
# ## Presentation
# The target of epyk is to ensure the implementation of a coherent system using a minimum of layers. With epyk the user stays in the Python layer to drive and optimize the data transformation. This Framework also encourages the implementation of Micro services and cloud based architecture.
#
# Find out more about the project design [here](project_design.ipynb)
#
# ## Tutorial
# Start with the [Jupyter configuration](tutorials/jupyter.ipynb) and some [Tutorial examples](tutorials.ipynb) and jump to any of the specific topic sections from there.
#
# ## Compatibility
# Epik is compatible with the most common Web Python Frameworks (Flask and Django). By default, the server package embeds a Flask app as it is easier to install and ready to use.
#
# Design is also flexible enought to be [extended](tutorials/extensions/01_framework_ext.ipynb)
#
# The Framework can be included within a Jupyter or JupyterLab project. But this will lead to some limitations - for example Ajax and Socket will not be available.
#
# It can also be used with any existing Python server. Most of the examples are implemented using Flask and FastApi but other web frameworks like Django or Tornado can easily integrate Epyk for the HTML pages generation.
#
# Click on the web framework to get more details:
#
# <div style="text-align:center">
#     <a href="servers/fastapi.ipynb">
#         <img src='static/images/fastapi.png' style="width:200px;display:inline-block;cursor:pointer;padding:15px" />
#     </a>
#     <a href="servers/django.ipynb">
#         <img src='static/images/django-logo.png' style="width:200px;display:inline-block;cursor:pointer;padding:15px" />
#     </a>
#     <a href="servers/flask.ipynb">
#         <img src='static/images/flask.png' style="width:200px;display:inline-block;cursor:pointer;padding:15px" />
#     </a>
#     <a href="servers/tornado.ipynb">
#         <img src='static/images/tornado.png' style="width:200px;display:inline-block;cursor:pointer;padding:15px" />
#     </a>
# </div>
#
# Real time events are also available for Network components using Socket-io. This can be used from any server.
#
# <div style="text-align:center">
#     <a href="servers/socketio.ipynb">
#         <img src='static/images/socketio.png' style="width:200px;display:inline-block;cursor:pointer;padding:15px" />
#     </a>
# </div>
#
# It is obviously also possible to use Epyk within any server by running the Python code and using your web browser for the page rendering.
#
# Report generated from Epyk can be integrated directly to the main Web Framework (React, Vue, Angular). Epyk can be also used to transpile JavaScript code which can be directly used from a Node server.
#
# <div style="text-align:center">
#     <a href="servers/react.ipynb">
#         <img src='static/images/react.png' style="width:200px;display:inline-block;cursor:pointer" />
#     </a>
#     <a href="servers/angular.ipynb">
#         <img src='static/images/angular-3-logo.png' style="width:200px;display:inline-block;cursor:pointer" />
#     </a>
#     <a href="servers/vue.ipynb">
#         <img src='static/images/vue.png' style="width:200px;display:inline-block;cursor:pointer" />
#     </a>
# </div>
#
# NodeJs ecosystem and set of features is not available from this on module as we would like to really as much as possible on the Python rich ecosystem to do all the backend transformation.
# Epyk should be used the same way than Jinja for advanced templating to generated dashboards and standard websites.
#
# <div style="text-align:center">
#     <a href="servers/nodejs.ipynb">
#         <img src='static/images/Node.js_logo.svg.png' style="margin:auto;width:200px;display:inline-block;cursor:pointer;margin-right:20px" />
#     </a>
#     <a href="servers/deno.ipynb">
#         <img src='static/images/Deno.svg.png' style="margin:auto;width:150px;display:inline-block;cursor:pointer" />
#     </a>
# </div>
#
# It is also possible to use some specific Epyk version on those web framework to reuse existing components and mix both worlds. More examples should be available soon
#
#
# ## Coming Soon
# Please get in touch if there is any features you feel Epyk-UI needs.
#
# In the next realeases, Epyk ecosystem will try to be more collaborative and to then be linked to popular framework using Nodejs - React and Angular mainly.

# %% [markdown]
# ## Useful Links
#
# Repositories are here available in GitHub:
#
# - [Epyk](https://github.com/epykure/epyk-ui):
# - [Epyk Materials](https://github.com/epykure/epyk-materials)
# - [Epyk Bootstrap](https://github.com/epykure/epyk-bootstrap)
# - [Epyk AWS](https://github.com/epykure/epyk-aws)
# - [Epyk Engine](https://github.com/epykure/epyk-engine) (In development)
# - [Epyk Flask](https://github.com/epykure/epyk-flask)
# - [Epyk Django](https://github.com/epykure/epyks-django) (In development)
# - [Epyk NodeJs](https://github.com/epykure/epyk-nodejs) (In development)
# - [Epyk Angular](https://github.com/epykure/epyk-angular) (In development)
#
#
# Also lot of template are there to help you to start
#
# - [Epyk templates](https://github.com/epykure/epyk-templates)
# - [Epyk Material templates](https://github.com/epykure/epyk-materials-templates)
# - [Epyk templates Bootstrap](https://github.com/epykure/epyk-templates-bootstrap)
# - [Epyk templates Codepen](https://github.com/epykure/epyk-templates-codepen)
# - [EPyk templates NodeJs](https://github.com/epykure/epyk-templates-nodejs)
#
#
# ## Videos Examples
#
# This section will be coming soon !
#
# <hr>
# Do not forget that this is a collaborative framework so do not hesitate to give feedbacks and like the different repository to get more visbility.
#
# Also any help is more than welcome !
